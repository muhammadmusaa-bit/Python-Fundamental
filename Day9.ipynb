# %%
from array import *

# %%
arr = array('i' , [12,34,56,78])

# %%
arr
# Out:
# array('i', [12, 34, 56, 78])

# %%
type(arr)
# Out:
# array.array

# %%
arr.append(60)

# %%
arr
# Out:
# array('i', [12, 34, 56, 78, 60])

# %%
arr.remove(12)

# %%
arr.tolist()
# Out:
# [34, 56, 78, 60]

# %%
arr2 = arr

# %%
arr2.append(23)

# %%
arr
arr2
# Out:
# array('i', [34, 56, 78, 60, 23])

# %%
arr_new = arr.tolist()

# %%
arr_new
# Out:
# [34, 56, 78, 60, 23]

# %%
arr.index(34)
# Out:
# 0

# %%
arr[2] = 34

# %%
arr
# Out:
# array('i', [34, 56, 34, 60, 23])

# %%
arr2
# Out:
# array('i', [34, 56, 34, 60, 23])

# %%
arr[3]
# Out:
# 60

# %%
# This is the end of day8 work
