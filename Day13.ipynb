# %%
# %%writefile hello.py
x = 10
print(f"Variable is {x}")
def hello():
  print("Here we go!")
hello()
# Out:
# Writing hello.py

# %%
# !python /content/hello.py
# Out:
# Variable is 10
# Here we go!

# %%
# !python '/content/drive/MyDrive/daa1/Hallo.py'
# Out:
# Helllo
# Message from vs code
