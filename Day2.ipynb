# %%
# List - Muttable

# %%
L = ["Ali" , "Musa" , "Raza"]

# %%
L
# Out:
# ['Ali', 'Musa', 'Raza']

# %%
N = [1,2,4,3,4,5,7]

# %%
N
# Out:
# [1, 2, 4, 3, 4, 5, 7]

# %%
Mix = ["Ali" , 12,3,4,6.4]

# %%
Mix
# Out:
# ['Ali', 12, 3, 4, 6.4]

# %%
N.sort() # Sort the values

# %%
N
# Out:
# [1, 2, 3, 4, 4, 5, 7]

# %%
N.append(13) # Add the value at the end

# %%
N
# Out:
# [1, 2, 3, 4, 4, 5, 7, 13]

# %%
N.count(1) # Count the number of values
# Out:
# 1

# %%
N.extend([12,3,4,5]) # Extend the list

# %%
N
# Out:
# [1, 2, 3, 4, 4, 5, 7, 13, 12, 3, 4, 5]

# %%
N.reverse() # Reverse the list

# %%
N
# Out:
# [5, 4, 3, 12, 13, 7, 5, 4, 4, 3, 2, 1]

# %%
N.remove(5) # Remove the number

# %%
N
# Out:
# [4, 3, 12, 13, 7, 5, 4, 4, 3, 2, 1]

# %%
N.pop(2) # Remove the number by mentiong index
# Out:
# 13

# %%
N
# Out:
# [4, 3, 7, 4, 4, 3, 2, 1]

# %%
ListOfList = [N,L]

# %%
ListOfList
# Out:
# [[4, 3, 7, 4, 4, 3, 2, 1], ['Ali', 'Musa', 'Raza']]

# %%
# Tuple - Immutable

# %%
tup = (1,3,4)

# %%
tup1 = ("Ali" , 2,3)

# %%
tup.count(1)
# Out:
# 1

# %%
tup.index(3)
# Out:
# 1

# %%
# Set - mutable , do not hold duplicacy
s = {1,2,3,4,5}

# %%
s
# Out:
# {1, 2, 3, 4, 5}

# %%
s.add(12) # Add number

# %%
s
# Out:
# {1, 2, 3, 4, 5, 12}

# %%
s.pop() # pop the digit
# Out:
# 2

# %%
s
# Out:
# {2, 3, 4, 5, 12}

# %%
s1 = {2,5,6,6}

# %%
s.union(s,s1) # Give union

# %%
s.intersection(s1) # Give intersaction
# Out:
# {5}
