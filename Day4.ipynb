# %%
# Using math module

# %%
import math

# %%
math.sqrt(56)
# Out:
# 7.483314773547883

# %%
math.floor(7.48)
# Out:
# 7

# %%
math.ceil(7.48)
# Out:
# 8

# %%
math.factorial(5)
# Out:
# 120

# %%
math.trunc(5.54577)
# Out:
# 5

# %%
# User input

# %%
a = input("Enter the firstname:- ")
b = input("Enter the lastname:- ")
c = a + " " + b
c
# Out:
# Enter the firstname:- Muhammad
# Enter the lastname:- Musa
# 'Muhammad Musa'

# %%
a = int(input("Enter the first number:- "))
b = int(input("Enter the seacond number"))
sum = a + b
sum
# Out:
# Enter the first number:- 23
# Enter the seacond number45
# 68

# %%
A = eval(input("Enter the Expression to evaluate:- "))
A
# Out:
# Enter the Expression to evaluate:- 33+56+67+56
# 212

# %%
# End of the work of day 04
