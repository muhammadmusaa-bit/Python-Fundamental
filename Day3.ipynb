# %%
# Operator in python

# %%
# Arthematic operator
x = 5 + 3
x
# Out:
# 8

# %%
x = 5 - 3
x
# Out:
# 2

# %%
x = 5 * 3
x
# Out:
# 15

# %%
x = 5 / 2
x
# Out:
# 2.5

# %%
x = 5 % 2
x
# Out:
# 1

# %%
x = 5 ** 3
x
# Out:
# 125

# %%
x  = 5 // 2
x
# Out:
# 2

# %%
# Comparision operator
x = 5 > 3
x
# Out:
# True

# %%
x = 5 < 3
x
# Out:
# False

# %%
x = 5 != 3
x
# Out:
# True

# %%
x = 5 == 5
x
# Out:
# True

# %%
x = 5 >= 5
x
# Out:
# True

# %%
x = 5 <= 6
x
# Out:
# True

# %%
# Assignment operator
x += 5
x
# Out:
# 6

# %%
x -= 5
x
# Out:
# 1

# %%
x *= 5
x
# Out:
# 5

# %%
x /= 5
x
# Out:
# 1.0

# %%
x //= 5
x
# Out:
# 0.0

# %%
x %= 5
x
# Out:
# 0.0

# %%
x **= 5
x
# Out:
# 0.0

# %%
# Logical operator
x = 5 > 3 and 5 >10
x
# Out:
# False

# %%
x < 3 and 5 >10
x
# Out:
# False

# %%
x = 5 > 4 or 5 == 5
x
# Out:
# True

# %%
# Membarship operator
x = 'a' in 'alpha'
x
# Out:
# True

# %%
x = 'a' not in 'alpha'
x
# Out:
# False

# %%
# Identity operator
x = [12,34,32]
y = x
z = [45,3,4]

# %%
y is x
# Out:
# True

# %%
y
# Out:
# [12, 34, 32]
