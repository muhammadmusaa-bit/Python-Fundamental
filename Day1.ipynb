# %%
print("Hello World")
# Out:
# Hello World

# %%
# This is comment

# %%
# Variables in python
# Number
a = 12
a
# Out:
# 12

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
flo = 12.4
flo
# Out:
# 12.4

# %%
print(type(flo))
# Out:
# <class 'float'>

# %%
flo2 = 22/7
flo2
# Out:
# 3.142857142857143

# %%
print(type(flo2))
# Out:
# <class 'float'>

# %%
com = 2+3j
com
# Out:
# (2+3j)

# %%
print(type(com))
# Out:
# <class 'complex'>

# %%
# String - Every thing on the keyboard that can be typed
st = "34u39dsndd"

# %%
print(type(st))
# Out:
# <class 'str'>

# %%
# Boolen
a = True
print(type(a))
# Out:
# <class 'bool'>

# %%
b = False
print(type(b))
# Out:
# <class 'bool'>

# %%
c = "True"
print(type(c))
# Out:
# <class 'str'>

# %%
print("This is the end of day1 work")
# Out:
# This is the end of day1 work
