# %%
# Non_paprmetrized constructor
class Car:
  def __init__(self):
    self.name = "Cororla"
    self.brand = "totyota"
car1 = Car()
car2 = Car()
print(car1.name)
# Out:
# Cororla

# %%
# Parameterized construter
class Employee:
  def __init__(self , name , role , age, salary ):
    self.name = name
    self.role = role
    self.age = age
    self.salary = salary
  def displayinfo(self):
    print(f"{self.name} is {self.role}. His age is {self.age} and his salary is {self.salary}")
  displayinfo(emp1)
  displayinfo(emp2)
  # Instantitation
emp1 = Employee("Musa" , "Ai Engineer" , 16 , "1000000")
emp2 = Employee("Haji" , "Cyber Security" , 15 ,  "1500000")
# Out:
# Musa is Ai Engineer. His age is 16 and his salary is 1000000
# Haji is Cyber Security. His age is 15 and his salary is 1500000

# %%
# Default Parameter
class Cat:
  pass
Cat1  = Cat()

# %%
Cat1
