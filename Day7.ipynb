# %%
m = "hello python"

# %%
len(m)
# Out:
# 12

# %%
m.lower()
# Out:
# 'hello python'

# %%
m.upper()
# Out:
# 'HELLO PYTHON'

# %%
m.title()
# Out:
# 'Hello Python'

# %%
m.strip()
# Out:
# 'hello python'

# %%
m.lstrip()
# Out:
# 'hello python'

# %%
m.rstrip()
# Out:
# 'hello python'

# %%
m.find("h")
# Out:
# 0

# %%
m.count("h")
# Out:
# 2

# %%
m.capitalize()
# Out:
# 'Hello python'

# %%
m.encode()
# Out:
# b'hello python'

# %%
m.center(2,'*')
# Out:
# 'hello python'

# %%
m = "Muhammad Musa"
m[0]
m[4]
# Out:
# 'm'

# %%
m[0:5]
# Out:
# 'Muham'

# %%
m[0:]
# Out:
# 'Muhammad Musa'

# %%
m[:]
# Out:
# 'Muhammad Musa'

# %%
# Assignment
# username = dfg123@gmail.com
a = "dfg123@gmail.com"
a[:3]
# Out:
# 'dfg'

# %%
a[3:6]
# Out:
# '123'

# %%
a.find("@")
# Out:
# 6

# %%
a[7:12]
# Out:
# 'gmail'

# %%
a.find(".")
# Out:
# 12

# %%
a[13:]
# Out:
# 'com'
