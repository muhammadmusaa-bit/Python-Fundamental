# %%
# Dictionary is mutable and its santax is like key : value

# %%
employee = {
    1 : "Ali" ,
    2 : "Musa" ,
    3 : "Babali",
    4 : "Mannat"
}
print(employee)
# Out:
# {1: 'Ali', 2: 'Musa', 3: 'Babali', 4: 'Mannat'}

# %%
employee.keys() # Give us keys
# Out:
# dict_keys([1, 2, 3, 4])

# %%
employee.items() # Give us items
# Out:
# dict_items([(1, 'Ali'), (2, 'Musa'), (3, 'Babali'), (4, 'Mannat')])

# %%
employee.values() # Give us values
# Out:
# dict_values(['Ali', 'Musa', 'Babali', 'Mannat'])

# %%
employee.pop(3) # Remove the value by mentioning key
# Out:
# 'Babali'

# %%
employee
# Out:
# {1: 'Ali', 2: 'Musa', 4: 'Mannat'}

# %%
employee.popitem() # Remove last key-value pair
# Out:
# (4, 'Mannat')

# %%
employee
# Out:
# {1: 'Ali', 2: 'Musa'}

# %%
newemployee = employee.copy() # Copy the dic again

# %%
newemployee
# Out:
# {1: 'Ali', 2: 'Musa'}

# %%
employee.setdefault((5,"Patrick")) # Set the default

# %%
employee
# Out:
# {1: 'Ali', 2: 'Musa', (5, 'Patrick'): None}

# %%
employee.get(6) # extract the key-value

# %%
print(employee.get(6)) # If not exisit , print none
# Out:
# None

# %%
# Loop on dictionary

# %%
for k , v in employee.items(): # Use item function to run loop
  print(k,v)
# Out:
# 1 Ali
# 2 Musa
# (5, 'Patrick') None
